# %%
import pandas as pd
import os
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('../test_audio_sig_values/barn1_D20220723T000059m428-Coto.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'flatness', 'continuity', 'pitch', 'freq_mod'], dtype='object')

# %%
plt.figure(figsize=(200,50))
plt.plot(data['Unnamed: 0'], data['pitch'])
plt.savefig('books_read.png')
