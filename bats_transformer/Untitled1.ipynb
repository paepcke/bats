# %%
import pandas as pd

# %%
predictions = pd.read_csv("predictions/random_seed_1.predictions")
originals = pd.read_csv("originals/random_seed_1.originals")

# %%
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
predictions[(predictions.FileIndex == 1) & (predictions.Minute > -0.118644)]
# Out:
#     Unnamed: 0  FileIndex  Hour    Minute   ParentDir  TimeInFile  \
# 59          59          1  -1.0 -0.084746  20220206.0   404.99997
# 60          60          1  -1.0 -0.050847  20220206.0   507.00000
# 61          61          1  -1.0 -0.016949  20220206.0   598.00000
# 62          62          1  -1.0  0.016949  14894711.0  2287.73780
# 63          63          1  -1.0  0.050847  13372791.0  2671.17680
#
#     PrecedingIntrvl  CallsPerSec  CallDuration         Fc      HiFreq  \
# 59        96.479996     7.277766      2.800644  59.984127  102.618340
# 60       101.088000     7.277766      3.125191  55.094208  100.704475
# 61        92.016000     7.277766      2.688958  59.984753  104.532010
# 62        76.013435     7.923681      3.019835  34.866684   60.172610
# 63        75.065880     7.898390      3.030125  33.551250   49.554390
#
#       LowFreq    Bndwdth  FreqMaxPwr  PrcntMaxAmpDur  TimeFromMaxToFc  \
# 59  58.754143  43.864200   59.752340        89.81732        -0.169310
# ...

# %%
originals[(originals.FileIndex == 1) & ((originals.Minute > -0.118644))]
# Out:
#     Unnamed: 0  FileIndex  Hour    Minute   ParentDir  TimeInFile  \
# 59          59          1  -1.0 -0.084746  20220206.0   404.99997
# 60          60          1  -1.0 -0.050847  20220206.0   507.00000
# 61          61          1  -1.0 -0.016949  20220206.0   598.00000
# 62          62          1  -1.0  0.016949  20220206.0   691.00000
# 63          63          1  -1.0  0.050847  20220206.0   783.00000
#
#     PrecedingIntrvl  CallsPerSec  CallDuration         Fc      HiFreq  \
# 59        96.479996     7.277766      2.800644  59.984127  102.618340
# 60       101.088000     7.277766      3.125191  55.094208  100.704475
# 61        92.016000     7.277766      2.688958  59.984753  104.532010
# 62        92.160000     7.277766      2.895680  57.677750  101.859245
# 63        91.584000     7.277766      2.099611  61.748142   90.886220
#
#       LowFreq    Bndwdth  FreqMaxPwr  PrcntMaxAmpDur  TimeFromMaxToFc  \
# 59  58.754143  43.864200   59.752340       89.817320        -0.169310
# ...
