# %%
import pandas as pd
import numpy

# %%
df = pd.read_csv("data/data_2.csv")

# %%
df
# Out:
#                                    Filename   ParentDir             NextDirUp  \
# 0        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 1        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 2        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 3        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 4        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# ...                                     ...         ...                   ...
# 114875  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114876  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114877  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114878  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114879  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
#
# ...

# %%
pd.set_option("display.max_rows", 500)

# %%
df.head().T
# Out:
#                                                         0  \
# Filename               barn1_D20220205T190035m593-LoF.wav
# ParentDir                                             NaN
# NextDirUp                                             NaN
# TimeInFile                                            NaN
# PrecedingIntrvl                                       NaN
# CallsPerSec                                           NaN
# CallDuration                                          NaN
# Fc                                                    NaN
# HiFreq                                                NaN
# LowFreq                                               NaN
# Bndwdth                                               NaN
# FreqMaxPwr                                            NaN
# PrcntMaxAmpDur                                        NaN
# TimeFromMaxToFc                                       NaN
# FreqKnee                                              NaN
# ...

# %%
df["TimeIndex"] = df.groupby("Filename").cumcount()

# %%
df
# Out:
#                                    Filename   ParentDir             NextDirUp  \
# 0        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 1        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 2        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 3        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# 4        barn1_D20220205T190035m593-LoF.wav         NaN                   NaN
# ...                                     ...         ...                   ...
# 114875  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114876  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114877  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114878  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
# 114879  barn1_D20220720T230524m116-Coto.wav  20220720.0  20220720_to_20220723
#
# ...
